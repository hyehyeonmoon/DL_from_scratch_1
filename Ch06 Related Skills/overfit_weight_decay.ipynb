# %%
# coding: utf-8
import os
import sys

sys.path.append(os.pardir)  # 부모 디렉터리의 파일을 가져올 수 있도록 설정
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from dataset.mnist import load_mnist
from common.multi_layer_net import MultiLayerNet
from common.optimizer import SGD

(x_train, t_train), (x_test, t_test) = load_mnist(normalize=True)

# 오버피팅을 재현하기 위해 학습 데이터 수를 줄임
x_train = x_train[:300]
t_train = t_train[:300]

# weight decay（가중치 감쇠） 설정 =======================
#weight_decay_lambda = 0 # weight decay를 사용하지 않을 경우
weight_decay_lambda = 0.1
# ====================================================

network = MultiLayerNet(input_size=784, hidden_size_list=[100, 100, 100, 100, 100, 100], output_size=10,
                        weight_decay_lambda=weight_decay_lambda)
optimizer = SGD(lr=0.01) # 학습률이 0.01인 SGD로 매개변수 갱신

max_epochs = 201
train_size = x_train.shape[0]
batch_size = 100

train_loss_list = []
train_acc_list = []
test_acc_list = []

iter_per_epoch = max(train_size / batch_size, 1)
epoch_cnt = 0

for i in range(1000000000):
    batch_mask = np.random.choice(train_size, batch_size)
    x_batch = x_train[batch_mask]
    t_batch = t_train[batch_mask]

    grads = network.gradient(x_batch, t_batch)
    optimizer.update(network.params, grads)

    if i % iter_per_epoch == 0:
        train_acc = network.accuracy(x_train, t_train)
        test_acc = network.accuracy(x_test, t_test)
        train_acc_list.append(train_acc)
        test_acc_list.append(test_acc)

        print("epoch:" + str(epoch_cnt) + ", train acc:" + str(train_acc) + ", test acc:" + str(test_acc))

        epoch_cnt += 1
        if epoch_cnt >= max_epochs:
            break

# 그래프 그리기
markers = {'train': 'o', 'test': 's'}
x = np.arange(max_epochs)
plt.plot(x, train_acc_list, marker='o', label='train', markevery=10)
plt.plot(x, test_acc_list, marker='s', label='test', markevery=10)
plt.xlabel("epochs")
plt.ylabel("accuracy")
plt.ylim(0, 1.0)
plt.legend(loc='lower right')
plt.show()
# Out:
# epoch:0, train acc:0.14, test acc:0.1255
# epoch:1, train acc:0.13666666666666666, test acc:0.1294
# epoch:2, train acc:0.16, test acc:0.136
# epoch:3, train acc:0.19, test acc:0.1466
# epoch:4, train acc:0.20333333333333334, test acc:0.1571
# epoch:5, train acc:0.22, test acc:0.1671
# epoch:6, train acc:0.23666666666666666, test acc:0.1695
# epoch:7, train acc:0.26, test acc:0.1746
# epoch:8, train acc:0.25666666666666665, test acc:0.179
# epoch:9, train acc:0.27666666666666667, test acc:0.1864
# epoch:10, train acc:0.3, test acc:0.189
# epoch:11, train acc:0.31, test acc:0.2033
# epoch:12, train acc:0.34, test acc:0.2027
# epoch:13, train acc:0.3466666666666667, test acc:0.2024
# epoch:14, train acc:0.36, test acc:0.2157
# epoch:15, train acc:0.37333333333333335, test acc:0.2257
# epoch:16, train acc:0.39666666666666667, test acc:0.2381
# epoch:17, train acc:0.4166666666666667, test acc:0.2439
# epoch:18, train acc:0.43666666666666665, test acc:0.2464
# epoch:19, train acc:0.45666666666666667, test acc:0.2583
# epoch:20, train acc:0.47, test acc:0.277
# epoch:21, train acc:0.48333333333333334, test acc:0.2927
# epoch:22, train acc:0.51, test acc:0.3102
# epoch:23, train acc:0.5366666666666666, test acc:0.3242
# epoch:24, train acc:0.55, test acc:0.3414
# epoch:25, train acc:0.57, test acc:0.3617
# epoch:26, train acc:0.57, test acc:0.3695
# epoch:27, train acc:0.5766666666666667, test acc:0.3785
# epoch:28, train acc:0.5866666666666667, test acc:0.3853
# epoch:29, train acc:0.59, test acc:0.389
# epoch:30, train acc:0.5933333333333334, test acc:0.4002
# epoch:31, train acc:0.6033333333333334, test acc:0.4131
# epoch:32, train acc:0.6166666666666667, test acc:0.4343
# epoch:33, train acc:0.65, test acc:0.4523
# epoch:34, train acc:0.66, test acc:0.4638
# epoch:35, train acc:0.6733333333333333, test acc:0.4746
# epoch:36, train acc:0.67, test acc:0.4887
# epoch:37, train acc:0.6833333333333333, test acc:0.5044
# epoch:38, train acc:0.7, test acc:0.5095
# epoch:39, train acc:0.6966666666666667, test acc:0.5078
# epoch:40, train acc:0.69, test acc:0.516
# epoch:41, train acc:0.6866666666666666, test acc:0.5167
# epoch:42, train acc:0.71, test acc:0.5187
# epoch:43, train acc:0.6933333333333334, test acc:0.5226
# epoch:44, train acc:0.7133333333333334, test acc:0.5262
# epoch:45, train acc:0.6966666666666667, test acc:0.5189
# epoch:46, train acc:0.7066666666666667, test acc:0.5361
# epoch:47, train acc:0.7133333333333334, test acc:0.5446
# epoch:48, train acc:0.7166666666666667, test acc:0.5442
# epoch:49, train acc:0.7066666666666667, test acc:0.5326
# epoch:50, train acc:0.7133333333333334, test acc:0.5387
# epoch:51, train acc:0.7166666666666667, test acc:0.5428
# epoch:52, train acc:0.72, test acc:0.5465
# epoch:53, train acc:0.75, test acc:0.5607
# epoch:54, train acc:0.7433333333333333, test acc:0.5769
# epoch:55, train acc:0.7466666666666667, test acc:0.5781
# epoch:56, train acc:0.74, test acc:0.5826
# epoch:57, train acc:0.7566666666666667, test acc:0.5834
# epoch:58, train acc:0.7533333333333333, test acc:0.5908
# epoch:59, train acc:0.7566666666666667, test acc:0.5999
# epoch:60, train acc:0.7566666666666667, test acc:0.6054
# epoch:61, train acc:0.7566666666666667, test acc:0.6051
# epoch:62, train acc:0.7566666666666667, test acc:0.6087
# epoch:63, train acc:0.7666666666666667, test acc:0.612
# epoch:64, train acc:0.7666666666666667, test acc:0.6125
# epoch:65, train acc:0.7566666666666667, test acc:0.6173
# epoch:66, train acc:0.77, test acc:0.6187
# epoch:67, train acc:0.77, test acc:0.618
# epoch:68, train acc:0.78, test acc:0.6223
# epoch:69, train acc:0.78, test acc:0.6211
# epoch:70, train acc:0.7633333333333333, test acc:0.6227
# epoch:71, train acc:0.7866666666666666, test acc:0.6295
# epoch:72, train acc:0.7866666666666666, test acc:0.627
# epoch:73, train acc:0.79, test acc:0.6359
# epoch:74, train acc:0.7933333333333333, test acc:0.6358
# epoch:75, train acc:0.7833333333333333, test acc:0.638
# epoch:76, train acc:0.8, test acc:0.6482
# epoch:77, train acc:0.81, test acc:0.6472
# epoch:78, train acc:0.8033333333333333, test acc:0.6414
# epoch:79, train acc:0.79, test acc:0.6413
# epoch:80, train acc:0.8033333333333333, test acc:0.6394
# epoch:81, train acc:0.81, test acc:0.6426
# epoch:82, train acc:0.8033333333333333, test acc:0.6387
# epoch:83, train acc:0.8, test acc:0.6402
# epoch:84, train acc:0.8166666666666667, test acc:0.6492
# epoch:85, train acc:0.8266666666666667, test acc:0.6534
# epoch:86, train acc:0.8333333333333334, test acc:0.6582
# epoch:87, train acc:0.8433333333333334, test acc:0.6609
# epoch:88, train acc:0.8366666666666667, test acc:0.6581
# epoch:89, train acc:0.8233333333333334, test acc:0.6613
# epoch:90, train acc:0.8433333333333334, test acc:0.6704
# epoch:91, train acc:0.8466666666666667, test acc:0.673
# epoch:92, train acc:0.84, test acc:0.6651
# epoch:93, train acc:0.8333333333333334, test acc:0.6646
# epoch:94, train acc:0.8466666666666667, test acc:0.6669
# epoch:95, train acc:0.8533333333333334, test acc:0.6729
# epoch:96, train acc:0.85, test acc:0.6705
# epoch:97, train acc:0.85, test acc:0.6652
# epoch:98, train acc:0.8633333333333333, test acc:0.673
# epoch:99, train acc:0.8633333333333333, test acc:0.6727
# epoch:100, train acc:0.8566666666666667, test acc:0.6704
# epoch:101, train acc:0.8566666666666667, test acc:0.6683
# epoch:102, train acc:0.87, test acc:0.6811
# epoch:103, train acc:0.8766666666666667, test acc:0.6867
# epoch:104, train acc:0.8666666666666667, test acc:0.6806
# epoch:105, train acc:0.8666666666666667, test acc:0.6787
# epoch:106, train acc:0.87, test acc:0.6774
# epoch:107, train acc:0.8533333333333334, test acc:0.6682
# epoch:108, train acc:0.8533333333333334, test acc:0.6715
# epoch:109, train acc:0.8566666666666667, test acc:0.6758
# epoch:110, train acc:0.8766666666666667, test acc:0.685
# epoch:111, train acc:0.87, test acc:0.6812
# epoch:112, train acc:0.8633333333333333, test acc:0.672
# epoch:113, train acc:0.8566666666666667, test acc:0.6736
# epoch:114, train acc:0.8766666666666667, test acc:0.6841
# epoch:115, train acc:0.8833333333333333, test acc:0.6853
# epoch:116, train acc:0.87, test acc:0.6819
# epoch:117, train acc:0.86, test acc:0.6781
# epoch:118, train acc:0.8866666666666667, test acc:0.6845
# epoch:119, train acc:0.8833333333333333, test acc:0.6918
# epoch:120, train acc:0.88, test acc:0.6831
# epoch:121, train acc:0.8733333333333333, test acc:0.6892
# epoch:122, train acc:0.88, test acc:0.6924
# epoch:123, train acc:0.8666666666666667, test acc:0.6861
# epoch:124, train acc:0.87, test acc:0.6854
# epoch:125, train acc:0.8733333333333333, test acc:0.6868
# epoch:126, train acc:0.8766666666666667, test acc:0.6846
# epoch:127, train acc:0.8933333333333333, test acc:0.6932
# epoch:128, train acc:0.8833333333333333, test acc:0.6903
# epoch:129, train acc:0.8866666666666667, test acc:0.6916
# epoch:130, train acc:0.8766666666666667, test acc:0.6841
# epoch:131, train acc:0.8833333333333333, test acc:0.69
# epoch:132, train acc:0.87, test acc:0.6816
# epoch:133, train acc:0.8766666666666667, test acc:0.6876
# epoch:134, train acc:0.88, test acc:0.6847
# epoch:135, train acc:0.8833333333333333, test acc:0.6872
# epoch:136, train acc:0.9033333333333333, test acc:0.6948
# epoch:137, train acc:0.89, test acc:0.6929
# epoch:138, train acc:0.8866666666666667, test acc:0.6842
# epoch:139, train acc:0.8766666666666667, test acc:0.6882
# epoch:140, train acc:0.8833333333333333, test acc:0.6869
# epoch:141, train acc:0.8766666666666667, test acc:0.6908
# epoch:142, train acc:0.9033333333333333, test acc:0.6919
# epoch:143, train acc:0.9066666666666666, test acc:0.6901
# epoch:144, train acc:0.9066666666666666, test acc:0.6964
# epoch:145, train acc:0.91, test acc:0.6846
# epoch:146, train acc:0.8933333333333333, test acc:0.6902
# epoch:147, train acc:0.8833333333333333, test acc:0.6895
# epoch:148, train acc:0.9033333333333333, test acc:0.6935
# epoch:149, train acc:0.8966666666666666, test acc:0.6927
# epoch:150, train acc:0.91, test acc:0.6908
# epoch:151, train acc:0.8966666666666666, test acc:0.6881
# epoch:152, train acc:0.8966666666666666, test acc:0.6883
# epoch:153, train acc:0.8833333333333333, test acc:0.6843
# epoch:154, train acc:0.9, test acc:0.6853
# epoch:155, train acc:0.89, test acc:0.6864
# epoch:156, train acc:0.9066666666666666, test acc:0.6877
# epoch:157, train acc:0.92, test acc:0.6891
# epoch:158, train acc:0.9133333333333333, test acc:0.6932
# epoch:159, train acc:0.9133333333333333, test acc:0.6979
# epoch:160, train acc:0.9033333333333333, test acc:0.6913
# epoch:161, train acc:0.9033333333333333, test acc:0.686
# epoch:162, train acc:0.8966666666666666, test acc:0.6882
# epoch:163, train acc:0.9, test acc:0.6878
# epoch:164, train acc:0.9066666666666666, test acc:0.6922
# epoch:165, train acc:0.9033333333333333, test acc:0.692
# epoch:166, train acc:0.9166666666666666, test acc:0.6951
# epoch:167, train acc:0.92, test acc:0.6922
# epoch:168, train acc:0.9066666666666666, test acc:0.692
# epoch:169, train acc:0.9133333333333333, test acc:0.6924
# epoch:170, train acc:0.9, test acc:0.6908
# epoch:171, train acc:0.91, test acc:0.6939
# epoch:172, train acc:0.9133333333333333, test acc:0.6965
# epoch:173, train acc:0.9166666666666666, test acc:0.6945
# epoch:174, train acc:0.91, test acc:0.6916
# epoch:175, train acc:0.9033333333333333, test acc:0.6834
# epoch:176, train acc:0.9, test acc:0.6881
# epoch:177, train acc:0.91, test acc:0.6857
# epoch:178, train acc:0.9, test acc:0.6885
# epoch:179, train acc:0.9, test acc:0.6842
# epoch:180, train acc:0.9066666666666666, test acc:0.6846
# epoch:181, train acc:0.9, test acc:0.6848
# epoch:182, train acc:0.9, test acc:0.6818
# epoch:183, train acc:0.9033333333333333, test acc:0.6837
# epoch:184, train acc:0.9, test acc:0.6932
# epoch:185, train acc:0.91, test acc:0.6884
# epoch:186, train acc:0.92, test acc:0.6906
# epoch:187, train acc:0.9166666666666666, test acc:0.6903
# epoch:188, train acc:0.9066666666666666, test acc:0.6849
# epoch:189, train acc:0.9066666666666666, test acc:0.6886
# epoch:190, train acc:0.9233333333333333, test acc:0.6934
# epoch:191, train acc:0.9233333333333333, test acc:0.6951
# epoch:192, train acc:0.9266666666666666, test acc:0.6909
# epoch:193, train acc:0.92, test acc:0.6927
# epoch:194, train acc:0.9066666666666666, test acc:0.6917
# epoch:195, train acc:0.91, test acc:0.6913
# epoch:196, train acc:0.9133333333333333, test acc:0.6899
# epoch:197, train acc:0.9066666666666666, test acc:0.6867
# epoch:198, train acc:0.91, test acc:0.6869
# epoch:199, train acc:0.91, test acc:0.6873
# epoch:200, train acc:0.9033333333333333, test acc:0.6883
