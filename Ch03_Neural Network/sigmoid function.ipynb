# %%
import numpy as np
import matplotlib.pylab as plt

# %%
#시그모이드 함수 구현
def sigmoid(x):
    return 1/(1+np.exp(-x))

# %%
#확인
x=np.array([-1,1,2])
sigmoid(x)
# Out:
# array([0.26894142, 0.73105858, 0.88079708])

# %%
#그래프
X = np.arange(-5.0, 5.0, 0.1)
Y = sigmoid(X)
plt.plot(X, Y)
plt.ylim(-0.1, 1.1)
plt.show()
